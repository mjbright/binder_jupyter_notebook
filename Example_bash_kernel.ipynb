# %% [markdown]
# # Example of using a [Jupyter](http://jupyter.org) notebook [bash kernel](https://github.com/takluyver/bash_kernel) on mybinder.org
#
# See how we can launch regular shell commands below:

# %%
ls -altr; date
# Out:
# total 36
# -rw-rw-r--  1 main main   12 May 16 08:36 requirements.txt
# -rw-rw-r--  1 main main  221 May 16 08:36 README.md
# -rw-rw-r--  1 main main 1289 May 16 08:36 Dockerfile
# drwxrwxr-x 14 main main 4096 May 16 08:36 .git
# drwxr-xr-x 27 main main 4096 May 16 08:40 ..
# -rw-rw-r--  1 main main 3998 May 16 08:56 metakernel_bash.ipynb
# drwxr-xr-x  2 main main 4096 May 16 08:58 .ipynb_checkpoints
# -rw-r--r--  1 main main 1072 May 16 08:58 Example_bash_kernel.ipynb
# drwxr-xr-x  5 main main 4096 May 16 08:58 .
# Mon May 16 08:58:41 UTC 2016

# %% [markdown]
# Hmm, that's OK, but what can I do with bash in a sandbox?
#
# Well just like with Project Jupyter with other languages
# - I can experiment
# - I can share my experiments
# - via a platform like Jupyter those shared experiments can be tutorials where others can play to learn
#
# # Bash array tutorial anyone?
# You can launch a live copy of my Bash array tutorial running on mybinder.org by clicking the link below
# [![Binder](http://mybinder.org/badge.svg)](http://mybinder.org/repo/mjbright/binder_jupyter_notebook/Tutorial_Bash_Arrays.ipynb)
#
# # ls tutorial anyone?
# You can launch a live copy of my ls tutorial running on mybinder.org by clicking the link below
# [![Binder](http://mybinder.org/badge.svg)](http://mybinder.org/repo/mjbright/binder_jupyter_notebook/Tutorial_ls.ipynb)

# %% [markdown]
# # So I say Kudos to
# - The Jupyter team for [Jupyter](http://jupyter.org)
# - The Binder Project for [mybinder](http://mybinder.org)
# - Thomas Kluyver (for [bash kernel](https://github.com/takluyver/bash_kernel))

# %%
wget -O - http://www.uleth.ca/research-services/sites/research-services/files/kudos_4.png 2>/dev/null | display
